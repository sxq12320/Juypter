# %%
import torch
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## 1 导入训练数据

# %%
x_data = torch.tensor([[1.0] , [2.0] , [3.0]])
y_data = torch.tensor([[3.0] , [5.0] , [7.0]])

# %% [markdown]
# ## 2 设计训练模型

# %%
class LinearModel(torch.nn.Module):
    def __init__(self):
        super(LinearModel , self).__init__()
        self.linear = torch.nn.Linear(1,1)
    def forward(self,x):
        y_pred = self.linear(x)
        return y_pred
Model = LinearModel()

# %% [markdown]
# ## 3 给定损失函数以及优化模型

# %%
criterion = torch.nn.MSELoss(size_average=False) # sum
optimizer = torch.optim.SGD(Model.parameters(),lr =0.05)

# %% [markdown]
# ## 4 进行训练

# %%
loss_list = []
epoch_list = []
w_list = []
b_list = []

for epoch in range(0 , 51 , 1):
    epoch_list.append(epoch)
    y_pred = Model(x_data)
    loss = criterion(y_pred , y_data)
    loss_list.append(loss.item()) # 转换成标量
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    w_list.append(Model.linear.weight.item())
    b_list.append(Model.linear.bias.item())

# %% [markdown]
# ## 5 打印日志

# %%
for e,l,w ,b in zip(epoch_list , loss_list , w_list , b_list):
    print(f'第{e}轮的时候，损失为{l:.6f}，权重为{w:.6f} , 偏置为{b:.6f} \n')
# Out:
# 第0轮的时候，损失为59.623936，权重为3.122254 , 偏置为1.570055
#
# 第1轮的时候，损失为26.284218，权重为1.209065 , 偏置为0.725686
#
# 第2轮的时候，损失为11.587410，权重为2.480962 , 偏置为1.282541
#
# 第3轮的时候，损失为5.108731，权重为1.638091 , 偏置为0.909201
#
# 第4轮的时候，损失为2.252762，权重为2.199243 , 偏置为1.153587
#
# 第5轮的时候，损失为0.993748，权重为1.828151 , 偏置为0.987965
#
# 第6轮的时候，损失为0.438703，权重为2.075961 , 偏置为1.094685
#
# 第7轮的时候，损失为0.193983，权重为1.912805 , 偏置为1.020703
#
# 第8轮的时候，损失为0.086065，权重为2.022456 , 偏置为1.066809
#
# 第9轮的时候，损失为0.038454，权重为1.950932 , 偏置为1.033293
#
# 第10轮的时候，损失为0.017429，权重为1.999652 , 偏置为1.052746
#
# 第11轮的时候，损失为0.008127，权重为1.968492 , 偏置为1.037131
#
# 第12轮的时候，损失为0.003996，权重为1.990325 , 偏置为1.044896
#
# 第13轮的时候，损失为0.002145，权重为1.976932 , 偏置为1.037233
#
# 第14轮的时候，损失为0.001302，权重为1.986887 , 偏置为1.039904
#
# 第15轮的时候，损失为0.000905，权重为1.981303 , 偏置为1.035800
#
# 第16轮的时候，损失为0.000707，权重为1.985999 , 偏置为1.036278
#
# 第17轮的时候，损失为0.000598，权重为1.983834 , 偏置为1.033795
#
# 第18轮的时候，损失为0.000529，权重为1.986189 , 偏置为1.033357
#
# 第19轮的时候，损失为0.000480，权重为1.985510 , 偏置为1.031636
#
# 第20轮的时候，损失为0.000441，权重为1.986814 , 偏置为1.030839
#
# 第21轮的时候，损失为0.000408，权重为1.986771 , 偏置为1.029499
#
# 第22轮的时候，损失为0.000378，权重为1.987592 , 偏置为1.028587
#
# 第23轮的时候，损失为0.000351，权重为1.987811 , 偏置为1.027455
#
# 第24轮的时候，损失为0.000326，权重为1.988402 , 偏置为1.026532
#
# 第25轮的时候，损失为0.000302，权重为1.988720 , 偏置为1.025531
#
# 第26轮的时候，损失为0.000281，权重为1.989194 , 偏置为1.024640
#
# 第27轮的时候，损失为0.000261，权重为1.989539 , 偏置为1.023732
#
# 第28轮的时候，损失为0.000243，权重为1.989946 , 偏置为1.022889
#
# 第29轮的时候，损失为0.000225，权重为1.990288 , 偏置为1.022055
#
# 第30轮的时候，损失为0.000209，权重为1.990651 , 偏置为1.021266
#
# 第31轮的时候，损失为0.000195，权重为1.990980 , 偏置为1.020495
#
# 第32轮的时候，损失为0.000181，权重为1.991311 , 偏置为1.019758
#
# 第33轮的时候，损失为0.000168，权重为1.991621 , 偏置为1.019044
#
# 第34轮的时候，损失为0.000156，权重为1.991925 , 偏置为1.018359
#
# 第35轮的时候，损失为0.000145，权重为1.992215 , 偏置为1.017696
#
# 第36轮的时候，损失为0.000135，权重为1.992496 , 偏置为1.017058
#
# 第37轮的时候，损失为0.000125，权重为1.992766 , 偏置为1.016443
#
# 第38轮的时候，损失为0.000116，权重为1.993028 , 偏置为1.015850
#
# 第39轮的时候，损失为0.000108，权重为1.993279 , 偏置为1.015278
#
# 第40轮的时候，损失为0.000100，权重为1.993521 , 偏置为1.014728
#
# 第41轮的时候，损失为0.000093，权重为1.993755 , 偏置为1.014197
#
# 第42轮的时候，损失为0.000087，权重为1.993980 , 偏置为1.013685
#
# 第43轮的时候，损失为0.000081，权重为1.994197 , 偏置为1.013191
#
# 第44轮的时候，损失为0.000075，权重为1.994406 , 偏置为1.012715
#
# 第45轮的时候，损失为0.000070，权重为1.994608 , 偏置为1.012257
#
# 第46轮的时候，损失为0.000065，权重为1.994802 , 偏置为1.011815
#
# 第47轮的时候，损失为0.000060，权重为1.994990 , 偏置为1.011389
#
# 第48轮的时候，损失为0.000056，权重为1.995171 , 偏置为1.010978
#
# 第49轮的时候，损失为0.000052，权重为1.995345 , 偏置为1.010582
#
# 第50轮的时候，损失为0.000048，权重为1.995513 , 偏置为1.010201

# %% [markdown]
# ## 6 绘制图像
